# %%
import pandas as pd
from glob import glob

# %%
glob('./Data/지역*.xls')
# Out:
# ['./Data/지역_위치별(주유소) (9).xls',
#  './Data/지역_위치별(주유소) (12).xls',
#  './Data/지역_위치별(주유소) (5).xls',
#  './Data/지역_위치별(주유소) (24).xls',
#  './Data/지역_위치별(주유소) (25).xls',
#  './Data/지역_위치별(주유소) (4).xls',
#  './Data/지역_위치별(주유소) (13).xls',
#  './Data/지역_위치별(주유소) (8).xls',
#  './Data/지역_위치별(주유소) (3).xls',
#  './Data/지역_위치별(주유소) (18).xls',
#  './Data/지역_위치별(주유소) (22).xls',
#  './Data/지역_위치별(주유소) (14).xls',
#  './Data/지역_위치별(주유소) (15).xls',
#  './Data/지역_위치별(주유소) (23).xls',
#  './Data/지역_위치별(주유소) (19).xls',
#  './Data/지역_위치별(주유소) (2).xls',
#  './Data/지역_위치별(주유소) (20).xls',
#  './Data/지역_위치별(주유소) (1).xls',
#  './Data/지역_위치별(주유소) (16).xls',
#  './Data/지역_위치별(주유소) (17).xls',
#  './Data/지역_위치별(주유소) (21).xls',
#  './Data/지역_위치별(주유소) (10).xls',
#  './Data/지역_위치별(주유소).xls',
#  './Data/지역_위치별(주유소) (7).xls',
#  './Data/지역_위치별(주유소) (6).xls',
#  './Data/지역_위치별(주유소) (11).xls']

# %%
stations_files = glob('./Data/지역*.xls')
stations_files
# Out:
# ['./Data/지역_위치별(주유소) (9).xls',
#  './Data/지역_위치별(주유소) (12).xls',
#  './Data/지역_위치별(주유소) (5).xls',
#  './Data/지역_위치별(주유소) (24).xls',
#  './Data/지역_위치별(주유소) (25).xls',
#  './Data/지역_위치별(주유소) (4).xls',
#  './Data/지역_위치별(주유소) (13).xls',
#  './Data/지역_위치별(주유소) (8).xls',
#  './Data/지역_위치별(주유소) (3).xls',
#  './Data/지역_위치별(주유소) (18).xls',
#  './Data/지역_위치별(주유소) (22).xls',
#  './Data/지역_위치별(주유소) (14).xls',
#  './Data/지역_위치별(주유소) (15).xls',
#  './Data/지역_위치별(주유소) (23).xls',
#  './Data/지역_위치별(주유소) (19).xls',
#  './Data/지역_위치별(주유소) (2).xls',
#  './Data/지역_위치별(주유소) (20).xls',
#  './Data/지역_위치별(주유소) (1).xls',
#  './Data/지역_위치별(주유소) (16).xls',
#  './Data/지역_위치별(주유소) (17).xls',
#  './Data/지역_위치별(주유소) (21).xls',
#  './Data/지역_위치별(주유소) (10).xls',
#  './Data/지역_위치별(주유소).xls',
#  './Data/지역_위치별(주유소) (7).xls',
#  './Data/지역_위치별(주유소) (6).xls',
#  './Data/지역_위치별(주유소) (11).xls']

# %%
tmp_raw = []

for file_name in stations_files:
    tmp = pd.read_excel(file_name, header = 2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw)

# %%
station_raw
# Out:
#        지역           상호                      주소      상표          전화번호 셀프여부  \
# 0   서울특별시      태릉솔밭주유소     서울 노원구 노원로 49 (공릉동)   S-OIL   02-976-5189    Y
# 1   서울특별시      배꽃나라주유소    서울 노원구 화랑로 466 (공릉동)   GS칼텍스   02-973-5172    Y
# 2   서울특별시        삼육주유소    서울 노원구 화랑로 822 (공릉동)   SK에너지   02-949-3677    Y
# 3   서울특별시        한신주유소   서울 노원구 동일로 1089 (공릉동)   SK에너지   02-974-5151    N
# 4   서울특별시       화랑대주유소          서울 노원구 화랑로 483   SK에너지   02-972-5189    Y
# ..    ...          ...                     ...     ...           ...  ...
# 17  서울특별시        신성주유소    서울 동대문구 장한로 29 (장안동)  현대오일뱅크  02-2217-4574    N
# 18  서울특별시      오동나무주유소  서울 동대문구  한천로 81 (답십리동)   S-OIL  02-2247-5132    N
# 19  서울특별시  대성산업㈜청량리주유소  서울 동대문구 왕산로 289 (청량리동)   GS칼텍스   02-966-9400    N
# 20  서울특별시   한영주유소 (한화)    서울 동대문구 망우로 38 (휘경동)  현대오일뱅크  02-2214-9890    N
# 21  서울특별시        능주주유소  서울 동대문구 청계천로 431 (신설동)   SK에너지  02-2232-4245    N
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1598  1324  1144     -
# 1   1598  1324  1144  1050
# 2      -  1325  1150  1000
# 3   1698  1328  1148  1040
# 4   1628  1328  1178  1000
# ..   ...   ...   ...   ...
# 17     -  1397  1197     -
# 18     -  1398  1198  1200
# 19     -  1399  1199     -
# 20     -  1455  1290   920
# 21     -  1505  1320     -
#
# [540 rows x 10 columns]

# %%
stations = pd.DataFrame({'Oil_store' : station_raw['상호'],
                            '주소' : station_raw['주소'],
                            '가격' : station_raw['휘발유'],
                            '셀프' : station_raw['셀프여부'],
                            '상표' : station_raw['상표']})

stations.head()
# Out:
#   Oil_store                     주소    가격 셀프     상표
# 0   태릉솔밭주유소    서울 노원구 노원로 49 (공릉동)  1324  Y  S-OIL
# 1   배꽃나라주유소   서울 노원구 화랑로 466 (공릉동)  1324  Y  GS칼텍스
# 2     삼육주유소   서울 노원구 화랑로 822 (공릉동)  1325  Y  SK에너지
# 3     한신주유소  서울 노원구 동일로 1089 (공릉동)  1328  N  SK에너지
# 4    화랑대주유소         서울 노원구 화랑로 483  1328  Y  SK에너지

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#   Oil_store                     주소    가격 셀프     상표    구
# 0   태릉솔밭주유소    서울 노원구 노원로 49 (공릉동)  1324  Y  S-OIL  노원구
# 1   배꽃나라주유소   서울 노원구 화랑로 466 (공릉동)  1324  Y  GS칼텍스  노원구
# 2     삼육주유소   서울 노원구 화랑로 822 (공릉동)  1325  Y  SK에너지  노원구
# 3     한신주유소  서울 노원구 동일로 1089 (공릉동)  1328  N  SK에너지  노원구
# 4    화랑대주유소         서울 노원구 화랑로 483  1328  Y  SK에너지  노원구

# %%
stations['구'].unique()
# Out:
# array(['노원구', '동작구', '관악구', '중구', '중랑구', '강남구', '마포구', '금천구', '강서구',
#        '송파구', '은평구', '서대문구', '서초구', '종로구', '양천구', '강북구', '영등포구', '강동구',
#        '성동구', '성북구', '용산구', '도봉구', '구로구', '광진구', '동대문구'], dtype=object)

# %% [markdown]
# - 원래 있어야 하지만 책 이후에는 업데이트 되어 없는 것으로 보임
# stations[stations['구']=='서울특별시']

# %%
stations[stations['구']=='관악구']
# Out:
#               Oil_store                          주소    가격 셀프      상표    구
# 0                 남현주유소     서울 관악구 남부순환로 2014 (남현동)  1327  Y  현대오일뱅크  관악구
# 1          서일석유(주)락성주유소     서울 관악구 남부순환로 1920 (봉천동)  1327  Y   GS칼텍스  관악구
# 2   현대오일뱅크(주)직영 관악셀프주유소     서울 관악구 남부순환로 1520 (신림동)  1335  Y  현대오일뱅크  관악구
# 3    (주)엠오티이엔지 직영 삼화주유소        서울 관악구 보라매로 41 (봉천동)  1348  N   알뜰주유소  관악구
# 4                 유림주유소        서울 관악구 신림로 176 (신림동)  1357  N   S-OIL  관악구
# 5        (주)연우에너지 신관주유소  서울 관악구 신림로 290 (신림동) 신관주유소  1358  Y   GS칼텍스  관악구
# 6      대양석유(주)직영 보라매주유소       서울 관악구  보라매로 26 (봉천동)  1359  Y   SK에너지  관악구
# 7                 현대주유소        서울 관악구 난곡로 108 (신림동)  1359  N  현대오일뱅크  관악구
# 8         지에스칼텍스㈜ 난곡주유소              서울 관악구 난곡로 206  1359  N   GS칼텍스  관악구
# 9       (주)한유에너지행운셀프주유소     서울 관악구 남부순환로 1883 (봉천동)  1385  Y   SK에너지  관악구
# 10              관악시몬주유소  서울특별시 관악구 남부순환로 1753 (봉천동)  1387  N   S-OIL  관악구
# 11               문성골주유소         서울 관악구 문성로 97 (신림동)  1388  N  현대오일뱅크  관악구
# 12           한규상사 유정주유소     서울 관악구 남부순환로 1691 (봉천동)  1389  N   SK에너지  관악구
# 13    SK에너지(주)직영 대공원주유소       서울 관악구 과천대로 921 (남현동)  1389  N   SK에너지  관악구
# 14         SK에너지(주) 신봉천     서울 관악구 남부순환로 1880 (봉천동)  1389  N   SK에너지  관악구
# 15        CJ대한통운㈜ 신림주유소     서울 관악구 남부순환로 1515 (신림동)  1423  N   GS칼텍스  관악구

# %%
stations.loc[stations['구']=='서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['노원구', '동작구', '관악구', '중구', '중랑구', '강남구', '마포구', '금천구', '강서구',
#        '송파구', '은평구', '서대문구', '서초구', '종로구', '양천구', '강북구', '영등포구', '강동구',
#        '성동구', '성북구', '용산구', '도봉구', '구로구', '광진구', '동대문구'], dtype=object)

# %% [markdown]
# - 원래 있어야 하지만 책 이후에는 업데이트 되어 없는 것으로 보임
# stations[stations['구']=='특별시']

# %%
stations
# Out:
#       Oil_store                      주소    가격 셀프      상표     구
# 0       태릉솔밭주유소     서울 노원구 노원로 49 (공릉동)  1324  Y   S-OIL   노원구
# 1       배꽃나라주유소    서울 노원구 화랑로 466 (공릉동)  1324  Y   GS칼텍스   노원구
# 2         삼육주유소    서울 노원구 화랑로 822 (공릉동)  1325  Y   SK에너지   노원구
# 3         한신주유소   서울 노원구 동일로 1089 (공릉동)  1328  N   SK에너지   노원구
# 4        화랑대주유소          서울 노원구 화랑로 483  1328  Y   SK에너지   노원구
# ..          ...                     ...   ... ..     ...   ...
# 17        신성주유소    서울 동대문구 장한로 29 (장안동)  1397  N  현대오일뱅크  동대문구
# 18      오동나무주유소  서울 동대문구  한천로 81 (답십리동)  1398  N   S-OIL  동대문구
# 19  대성산업㈜청량리주유소  서울 동대문구 왕산로 289 (청량리동)  1399  N   GS칼텍스  동대문구
# 20   한영주유소 (한화)    서울 동대문구 망우로 38 (휘경동)  1455  N  현대오일뱅크  동대문구
# 21        능주주유소  서울 동대문구 청계천로 431 (신설동)  1505  N   SK에너지  동대문구
#
# [540 rows x 6 columns]

# %%
stations[stations['가격']=='-']
# Out:
#        Oil_store                         주소 가격 셀프      상표    구
# 39         삼성주유소       서울 강남구 삼성로 521 (삼성동)  -  N   SK에너지  강남구
# 40         동우주유소  서울특별시 강남구  봉은사로 311 (논현동)  -  N   SK에너지  강남구
# 12         서강주유소       서울 마포구 독막로 134 (창전동)  -  N   SK에너지  마포구
# 16         삼융주유소       서울 은평구 수색로 299 (수색동)  -  N   SK에너지  은평구
# 35        전당앞주유소    서울 서초구 남부순환로 2391 (서초동)  -  N   SK에너지  서초구
# 16  현대오일뱅크 성수주유소     서울 성동구 뚝섬로 352 (성수동1가)  -  N  현대오일뱅크  성동구
# 23        신동방주유소        서울 성북구 월계로 84 (장위동)  -  N   S-OIL  성북구
# 39         삼성주유소       서울 강남구 삼성로 521 (삼성동)  -  N   SK에너지  강남구
# 40         동우주유소  서울특별시 강남구  봉은사로 311 (논현동)  -  N   SK에너지  강남구

# %%
stations = stations[stations['가격'] != '-']
stations.head()
# Out:
#   Oil_store                     주소    가격 셀프     상표    구
# 0   태릉솔밭주유소    서울 노원구 노원로 49 (공릉동)  1324  Y  S-OIL  노원구
# 1   배꽃나라주유소   서울 노원구 화랑로 466 (공릉동)  1324  Y  GS칼텍스  노원구
# 2     삼육주유소   서울 노원구 화랑로 822 (공릉동)  1325  Y  SK에너지  노원구
# 3     한신주유소  서울 노원구 동일로 1089 (공릉동)  1328  N  SK에너지  노원구
# 4    화랑대주유소         서울 노원구 화랑로 483  1328  Y  SK에너지  노원구

# %%
stations['가격'] = [float(value) for value in stations['가격']]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 6 columns):
# Oil_store    531 non-null object
# 주소           531 non-null object
# 가격           531 non-null float64
# 셀프           531 non-null object
# 상표           531 non-null object
# 구            531 non-null object
# dtypes: float64(1), object(5)
# memory usage: 25.0+ KB

# %% [markdown]
# # 이제부터 정말 저렴한지 BoxPlot으로 확인해보자

# %%
# 한글 폰트

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform
from matplotlib import font_manager, rc
rc('font', family='NanumGothic')

# %%
stations.boxplot(column='가격', by='셀프', figsize=(12,8))

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', hue='셀프', data=stations, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', data=stations, palette = 'Set3')
sns.swarmplot(x='상표', y='가격', data=stations, color = '.6')
plt.show()
