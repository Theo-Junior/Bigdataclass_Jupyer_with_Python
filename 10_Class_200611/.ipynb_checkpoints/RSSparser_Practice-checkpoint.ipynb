# %% [markdown]
# pip install feedparser

# %% [markdown]
# pip3 install newspaper3k

# %%
import feedparser
import newspaper

from konlpy.tag import Kkma
from collections import Counter
from wordcloud import WordCloud

feeds = feedparser.parse("https://media.daum.net/syndication/today_sisa.rss")

# %%
feeds
# Out:
# {'feed': {'language': 'ko',
#   'title': '다음뉴스 - 시사 주요뉴스 RSS',
#   'title_detail': {'type': 'text/plain',
#    'language': 'ko-KR',
#    'base': 'https://media.daum.net/syndication/today_sisa.rss',
#    'value': '다음뉴스 - 시사 주요뉴스 RSS'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://media.daum.net/society/'}],
#   'link': 'http://media.daum.net/society/',
#   'subtitle': '',
#   'subtitle_detail': {'type': 'text/html',
#    'language': 'ko-KR',
#    'base': 'https://media.daum.net/syndication/today_sisa.rss',
#    'value': ''},
#   'rights': 'Copyright (c) Kakao Corp. All rights reserved.',
#   'rights_detail': {'type': 'text/plain',
#    'language': 'ko-KR',
#    'base': 'https://media.daum.net/syndication/today_sisa.rss',
#    'value': 'Copyright (c) Kakao Corp. All rights reserved.'},
#   'published': 'Thu, 11 Jun 2020 07:14:10 GMT',
#   'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=14, tm_sec=10, tm_wday=3, tm_yday=163, tm_isdst=0),
#   'authors': [{'name': '다음뉴스'}],
#   'author': '다음뉴스',
#   'author_detail': {'name': '다음뉴스'},
#   'updated': '2020-06-11T07:14:10Z',
#   'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=14, tm_sec=10, tm_wday=3, tm_yday=163, tm_isdst=0)},
#  'entries': [{'title': "쿠팡관련 부천·인천 493개교 '등교 재개'..학생·교직원 14명 확진(종합)",
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "쿠팡관련 부천·인천 493개교 '등교 재개'..학생·교직원 14명 확진(종합)"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611161255366'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/NEWS1/20200611161255800cver.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611161255366',
#    'summary': '(서울=뉴스1) 장지훈 기자,정지형 기자 = 쿠팡물류센터발(發) 신종 코로나바이러스 감염증(코로나19) 여파로 등교수업을 중지했던 부천·인천지역 학교 493곳이 11일 등교수업을 재개하면서 등교 중지 학교가 16곳으로 급감했다. 교육부에 따르면 이날 오전 10시 기준 등교를 중지한 학교는 인천 4곳, 서울 3곳, 경기 안양 1곳, 경기 성남 1곳, 경',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(서울=뉴스1) 장지훈 기자,정지형 기자 = 쿠팡물류센터발(發) 신종 코로나바이러스 감염증(코로나19) 여파로 등교수업을 중지했던 부천·인천지역 학교 493곳이 11일 등교수업을 재개하면서 등교 중지 학교가 16곳으로 급감했다. 교육부에 따르면 이날 오전 10시 기준 등교를 중지한 학교는 인천 4곳, 서울 3곳, 경기 안양 1곳, 경기 성남 1곳, 경'},
#    'published': 'Thu, 11 Jun 2020 07:12:55 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=12, tm_sec=55, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611161255366',
#    'guidislink': False,
#    'authors': [{'name': '뉴스1'}],
#    'author': '뉴스1',
#    'author_detail': {'name': '뉴스1'},
#    'updated': '2020-06-11T07:12:55Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=12, tm_sec=55, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '미 근로자 "경제적 손해지만 그래도 재택근무 희망"',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '미 근로자 "경제적 손해지만 그래도 재택근무 희망"'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611161249355'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/yonhap/20200611161249590liqw.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611161249355',
#    'summary': "(서울=연합뉴스) 구정모 기자 = 신종 코로나바이러스 감염증(코로나19) 여파로 재택근무를 경험한 미국 근로자들은 직장 출근 때보다 지출이 늘었지만 그래도 재택근무를 선호한다는 설문 조사 결과가 나왔다고 폭스 비즈니스가 10일(현지시간) 보도했다. 신용카드 서비스 비교 업체인 '크레딧카즈닷컴'이 지난달 재택근무 경험자 822명 등 성인 2천768명을 상대로",
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "(서울=연합뉴스) 구정모 기자 = 신종 코로나바이러스 감염증(코로나19) 여파로 재택근무를 경험한 미국 근로자들은 직장 출근 때보다 지출이 늘었지만 그래도 재택근무를 선호한다는 설문 조사 결과가 나왔다고 폭스 비즈니스가 10일(현지시간) 보도했다. 신용카드 서비스 비교 업체인 '크레딧카즈닷컴'이 지난달 재택근무 경험자 822명 등 성인 2천768명을 상대로"},
#    'published': 'Thu, 11 Jun 2020 07:12:49 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=12, tm_sec=49, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611161249355',
#    'guidislink': False,
#    'authors': [{'name': '연합뉴스'}],
#    'author': '연합뉴스',
#    'author_detail': {'name': '연합뉴스'},
#    'updated': '2020-06-11T07:12:49Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=12, tm_sec=49, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '2년 만에 하나 했더니..제주도·의회 정책협의회 결국 무산',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '2년 만에 하나 했더니..제주도·의회 정책협의회 결국 무산'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611161054250'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/NEWS1/20200611161054723jsum.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611161054250',
#    'summary': '(제주=뉴스1) 오미란 기자 = 민선 7기 원희룡 제주도정과 제11대 제주도의회 출범과 함께 설치됐던 \'제주도·제주도의회 상설정책협의회\'가 2년 만에 처음으로 열리는 듯 했으나 끝내 무산됐다. 제주도의회 의회운영위원회는 11일 오후 3시 제주도의회 기자실에서 기자회견을 열고 "신종 코로나 바이러스 감염증(코로나19)에 대한 제주도의 인식에 대해 많은 부',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(제주=뉴스1) 오미란 기자 = 민선 7기 원희룡 제주도정과 제11대 제주도의회 출범과 함께 설치됐던 \'제주도·제주도의회 상설정책협의회\'가 2년 만에 처음으로 열리는 듯 했으나 끝내 무산됐다. 제주도의회 의회운영위원회는 11일 오후 3시 제주도의회 기자실에서 기자회견을 열고 "신종 코로나 바이러스 감염증(코로나19)에 대한 제주도의 인식에 대해 많은 부'},
#    'published': 'Thu, 11 Jun 2020 07:10:54 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=10, tm_sec=54, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611161054250',
#    'guidislink': False,
#    'authors': [{'name': '뉴스1'}],
#    'author': '뉴스1',
#    'author_detail': {'name': '뉴스1'},
#    'updated': '2020-06-11T07:10:54Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=10, tm_sec=54, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '\'한살배기 학대의혹\' 울산 어린이집 A등급 논란.."과거에도 학대"',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '\'한살배기 학대의혹\' 울산 어린이집 A등급 논란.."과거에도 학대"'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160933191'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/newsis/20200611160933310pvdb.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160933191',
#    'summary': '[울산=뉴시스]구미현 기자 = 울산의 한 국공립어린이집이 만 1세 원아 학대 정황으로 물의를 빚고 있는 가운데 과거에도 비슷한 사건이 발생한 것으로 알려져 학부모들의 공분을 사고 있다. 또 이 어린이집이 지난해 평가인증에서 고득점을 받은 것으로 확인돼 관할당국의 허술한 관리 점검이 도마 위에 올랐다. 11일 중구에 따르면 최근 아동복지법 위반 혐의로',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '[울산=뉴시스]구미현 기자 = 울산의 한 국공립어린이집이 만 1세 원아 학대 정황으로 물의를 빚고 있는 가운데 과거에도 비슷한 사건이 발생한 것으로 알려져 학부모들의 공분을 사고 있다. 또 이 어린이집이 지난해 평가인증에서 고득점을 받은 것으로 확인돼 관할당국의 허술한 관리 점검이 도마 위에 올랐다. 11일 중구에 따르면 최근 아동복지법 위반 혐의로'},
#    'published': 'Thu, 11 Jun 2020 07:09:33 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=9, tm_sec=33, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160933191',
#    'guidislink': False,
#    'authors': [{'name': '뉴시스'}],
#    'author': '뉴시스',
#    'author_detail': {'name': '뉴시스'},
#    'updated': '2020-06-11T07:09:33Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=9, tm_sec=33, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '영국 엘리자베스 여왕의 6.25전쟁 70년 메시지는?',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '영국 엘리자베스 여왕의 6.25전쟁 70년 메시지는?'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160928189'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/kbs/20200611160928251tuwj.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160928189',
#    'summary': '강경화 외교부 장관은 어제(10일) 오후 도미닉 랍 영국 외교부 장관과 통화하고 코로나19 대응 등 다양한 현안에 대해 논의했습니다. 통화에서 랍 장관은 "양국 관계에 각별한 의미를 지닌 6·25 전쟁 70주년을 맞이하여 엘리자베스 2세 영국 여왕이 양국 국민들에게 보내는 특별한 메시지를 준비하고 있다"고 밝혔습니다. 올해 한국전쟁 70주년을 맞아 우리',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '강경화 외교부 장관은 어제(10일) 오후 도미닉 랍 영국 외교부 장관과 통화하고 코로나19 대응 등 다양한 현안에 대해 논의했습니다. 통화에서 랍 장관은 "양국 관계에 각별한 의미를 지닌 6·25 전쟁 70주년을 맞이하여 엘리자베스 2세 영국 여왕이 양국 국민들에게 보내는 특별한 메시지를 준비하고 있다"고 밝혔습니다. 올해 한국전쟁 70주년을 맞아 우리'},
#    'published': 'Thu, 11 Jun 2020 07:09:28 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=9, tm_sec=28, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160928189',
#    'guidislink': False,
#    'authors': [{'name': 'KBS'}],
#    'author': 'KBS',
#    'author_detail': {'name': 'KBS'},
#    'updated': '2020-06-11T07:09:28Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=9, tm_sec=28, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '정부, 전단 살포 단체 수사 의뢰..교류협력법 등 적용(종합)',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '정부, 전단 살포 단체 수사 의뢰..교류협력법 등 적용(종합)'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160911176'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/newsis/20200611160911684ksss.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160911176',
#    'summary': '[서울=뉴시스] 김지현 기자 = 통일부는 11일 서울경찰청에 북한으로 전단과 쌀 등을 살포한 탈북민 단체 2곳에 대한 수사를 의뢰했다고 밝혔다. 통일부는 이날 "자유북한운동연합(대표 박상학)과 큰샘(대표 박정오)의 대북 전단 및 PET(페트)병 살포 행위에 대해 서울지방경찰청에 수사를 의뢰했다"고 밝혔다. 통일부는 "두 단체의 대북 전단 및 페트병 살포',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '[서울=뉴시스] 김지현 기자 = 통일부는 11일 서울경찰청에 북한으로 전단과 쌀 등을 살포한 탈북민 단체 2곳에 대한 수사를 의뢰했다고 밝혔다. 통일부는 이날 "자유북한운동연합(대표 박상학)과 큰샘(대표 박정오)의 대북 전단 및 PET(페트)병 살포 행위에 대해 서울지방경찰청에 수사를 의뢰했다"고 밝혔다. 통일부는 "두 단체의 대북 전단 및 페트병 살포'},
#    'published': 'Thu, 11 Jun 2020 07:09:11 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=9, tm_sec=11, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160911176',
#    'guidislink': False,
#    'authors': [{'name': '뉴시스'}],
#    'author': '뉴시스',
#    'author_detail': {'name': '뉴시스'},
#    'updated': '2020-06-11T07:09:11Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=9, tm_sec=11, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '은성수 "공매도 제도 개선..필요하면 금지 연장"',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '은성수 "공매도 제도 개선..필요하면 금지 연장"'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160854144'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/NEWS1/20200611160854581hpas.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160854144',
#    'summary': '(서울=뉴스1) 박기호 기자,민정혜 기자 = 은성수 금융위원장은 오는 9월까지인 공매도 금지 조치에 대해 "다시 환원(해제)를 해도 갑자기 하지 않고 필요하면 제도를 개선하겠다"며 "연장이 필요하면 연장을 하겠다"고 밝혔다. 은 위원장은 11일 오후 정부서울청사에서 열린 하반기 금융정책 방향 관련 기자간담회에서 \'공매도 금지 연장 가능성\'에 대한 질문에',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(서울=뉴스1) 박기호 기자,민정혜 기자 = 은성수 금융위원장은 오는 9월까지인 공매도 금지 조치에 대해 "다시 환원(해제)를 해도 갑자기 하지 않고 필요하면 제도를 개선하겠다"며 "연장이 필요하면 연장을 하겠다"고 밝혔다. 은 위원장은 11일 오후 정부서울청사에서 열린 하반기 금융정책 방향 관련 기자간담회에서 \'공매도 금지 연장 가능성\'에 대한 질문에'},
#    'published': 'Thu, 11 Jun 2020 07:08:54 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=8, tm_sec=54, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160854144',
#    'guidislink': False,
#    'authors': [{'name': '뉴스1'}],
#    'author': '뉴스1',
#    'author_detail': {'name': '뉴스1'},
#    'updated': '2020-06-11T07:08:54Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=8, tm_sec=54, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '확진자 급증에 印지방 일부 재봉쇄..파키스탄선 야당 리더 감염(종합)',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '확진자 급증에 印지방 일부 재봉쇄..파키스탄선 야당 리더 감염(종합)'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160629031'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/yonhap/20200611160629633fgrk.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160629031',
#    'summary': '(뉴델리=연합뉴스) 김영현 특파원 = 신종 코로나바이러스 감염증(코로나19) 급속 확산에도 불구하고 봉쇄 조치를 완화해 나가던 인도에서 일부 지방정부가 다시 통제 고삐를 쥐고 있다. 봉쇄 완화 후 확진자 급증세에 놀란 주 정부들이 이동 제한 조치 등을 재도입하는 것이다. 11일 PTI통신 등 현지 언론에 따르면 서부 라자스탄 주정부는 10일부터 주 경계를',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(뉴델리=연합뉴스) 김영현 특파원 = 신종 코로나바이러스 감염증(코로나19) 급속 확산에도 불구하고 봉쇄 조치를 완화해 나가던 인도에서 일부 지방정부가 다시 통제 고삐를 쥐고 있다. 봉쇄 완화 후 확진자 급증세에 놀란 주 정부들이 이동 제한 조치 등을 재도입하는 것이다. 11일 PTI통신 등 현지 언론에 따르면 서부 라자스탄 주정부는 10일부터 주 경계를'},
#    'published': 'Thu, 11 Jun 2020 07:06:29 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=6, tm_sec=29, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160629031',
#    'guidislink': False,
#    'authors': [{'name': '연합뉴스'}],
#    'author': '연합뉴스',
#    'author_detail': {'name': '연합뉴스'},
#    'updated': '2020-06-11T07:06:29Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=6, tm_sec=29, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '靑 "평등경제는 경제민주주의 \'코로나 버전\'..포용성장·공정경제 연장선"',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '靑 "평등경제는 경제민주주의 \'코로나 버전\'..포용성장·공정경제 연장선"'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160605009'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/NEWS1/20200611160605406vlko.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160605009',
#    'summary': '(서울=뉴스1) 최은지 기자 = 문재인 대통령이 전날(10일) 제33주년 6·10민주항쟁 기념식에서 언급한 \'평등한 경제\'에 대해 청와대는 "경제 민주주의의 \'코로나 버전\'이 평등경제"라고 설명했다. 강민석 청와대 대변인은 11일 오후 춘추관에서 브리핑을 열고 "평등경제는 우리 정부의 핵심 경제기조인 포용성장과 공정경제의 연장선에 있는 말이기도 하다"라',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(서울=뉴스1) 최은지 기자 = 문재인 대통령이 전날(10일) 제33주년 6·10민주항쟁 기념식에서 언급한 \'평등한 경제\'에 대해 청와대는 "경제 민주주의의 \'코로나 버전\'이 평등경제"라고 설명했다. 강민석 청와대 대변인은 11일 오후 춘추관에서 브리핑을 열고 "평등경제는 우리 정부의 핵심 경제기조인 포용성장과 공정경제의 연장선에 있는 말이기도 하다"라'},
#    'published': 'Thu, 11 Jun 2020 07:06:05 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=6, tm_sec=5, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160605009',
#    'guidislink': False,
#    'authors': [{'name': '뉴스1'}],
#    'author': '뉴스1',
#    'author_detail': {'name': '뉴스1'},
#    'updated': '2020-06-11T07:06:05Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=6, tm_sec=5, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '최서원, 모든 재판 마쳤다..총형량 21년→출소 2037년',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '최서원, 모든 재판 마쳤다..총형량 21년→출소 2037년'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160601999'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/newsis/20200611160601542dyod.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160601999',
#    'summary': "[서울=뉴시스] 김재환 기자 = 박근혜 정부 비선실세로 불리면서 '국정농단'을 벌인 혐의를 받는 최서원(64·개명 전 최순실)씨에 대한 재판이 모두 일단락됐다. 최씨는 구속상태에서 재판에 넘겨진 지 1300일째가 되는 날 징역 18년형을 확정받았다. 딸의 입시 비리로 선고받은 징역 3년형을 더한다면 최씨는 오는 2037년께까지 복역해야 한다. 11일 법원",
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "[서울=뉴시스] 김재환 기자 = 박근혜 정부 비선실세로 불리면서 '국정농단'을 벌인 혐의를 받는 최서원(64·개명 전 최순실)씨에 대한 재판이 모두 일단락됐다. 최씨는 구속상태에서 재판에 넘겨진 지 1300일째가 되는 날 징역 18년형을 확정받았다. 딸의 입시 비리로 선고받은 징역 3년형을 더한다면 최씨는 오는 2037년께까지 복역해야 한다. 11일 법원"},
#    'published': 'Thu, 11 Jun 2020 07:06:01 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=6, tm_sec=1, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160601999',
#    'guidislink': False,
#    'authors': [{'name': '뉴시스'}],
#    'author': '뉴시스',
#    'author_detail': {'name': '뉴시스'},
#    'updated': '2020-06-11T07:06:01Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=6, tm_sec=1, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '홍콩, 외국인이 살기에 가장 비싼 도시..서울은 11위',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '홍콩, 외국인이 살기에 가장 비싼 도시..서울은 11위'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160552985'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/yonhap/20200611160553016sxts.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160552985',
#    'summary': "(서울=연합뉴스) 김계환 기자 = 홍콩이 전 세계에서 외국인이 살기에 가장 돈이 많이 드는 도시로 3년 연속 꼽혔다. 10일(현지시간) 미 경제 매체 CNBC 보도에 따르면 컨설팅업체 머서가 전 세계 209개 도시를 대상으로 지난 3월 실시한 '2020년 생활비 조사' 결과에서 홍콩이 외국인이 살기에 가장 비싼 도시로 3년째 선정됐다. 지난해 7위였던 투",
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "(서울=연합뉴스) 김계환 기자 = 홍콩이 전 세계에서 외국인이 살기에 가장 돈이 많이 드는 도시로 3년 연속 꼽혔다. 10일(현지시간) 미 경제 매체 CNBC 보도에 따르면 컨설팅업체 머서가 전 세계 209개 도시를 대상으로 지난 3월 실시한 '2020년 생활비 조사' 결과에서 홍콩이 외국인이 살기에 가장 비싼 도시로 3년째 선정됐다. 지난해 7위였던 투"},
#    'published': 'Thu, 11 Jun 2020 07:05:52 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=5, tm_sec=52, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160552985',
#    'guidislink': False,
#    'authors': [{'name': '연합뉴스'}],
#    'author': '연합뉴스',
#    'author_detail': {'name': '연합뉴스'},
#    'updated': '2020-06-11T07:05:52Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=5, tm_sec=52, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '"버스기사 끌고 다니며 음주측정 강요..심각한 인권탄압"',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '"버스기사 끌고 다니며 음주측정 강요..심각한 인권탄압"'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160520961'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/NEWS1/20200611160520721uawd.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160520961',
#    'summary': '(광주=뉴스1) 허단비 기자 = 광주 한 버스 운수업체에서 직장 내 괴롭힘과 부당노동행위가 벌어졌다며 운수 노동자들이 이를 규탄하고 나섰다. 민주노총 공공운수노조 광주전남지역버스지부는 11일 오후 광주시청 앞에서 기자회견을 열고 A운수업체의 직장 내 괴롭힘과 부당노동행위로 심각한 인권탄압을 당했다며 광주시에 철저한 관리감독을 촉구했다. 이들은 광주시',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(광주=뉴스1) 허단비 기자 = 광주 한 버스 운수업체에서 직장 내 괴롭힘과 부당노동행위가 벌어졌다며 운수 노동자들이 이를 규탄하고 나섰다. 민주노총 공공운수노조 광주전남지역버스지부는 11일 오후 광주시청 앞에서 기자회견을 열고 A운수업체의 직장 내 괴롭힘과 부당노동행위로 심각한 인권탄압을 당했다며 광주시에 철저한 관리감독을 촉구했다. 이들은 광주시'},
#    'published': 'Thu, 11 Jun 2020 07:05:20 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=5, tm_sec=20, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160520961',
#    'guidislink': False,
#    'authors': [{'name': '뉴스1'}],
#    'author': '뉴스1',
#    'author_detail': {'name': '뉴스1'},
#    'updated': '2020-06-11T07:05:20Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=5, tm_sec=20, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': "포항11·15지진범대위, 시행령 개정시 '실질적 배상' 반영 촉구",
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "포항11·15지진범대위, 시행령 개정시 '실질적 배상' 반영 촉구"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160252833'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/newsis/20200611160252534sost.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160252833',
#    'summary': '[포항=뉴시스] 강진구 기자 = 경북 포항11·15촉발지진 범시민대책위원회(공동위원장 이대공 김재동 허상호 공원식·이하 범대위)는 "정부가 추진하는 시행령 2차 개정 시 피해주민들에 대한 실질적인 배상 내용이 충분히 반영돼야 한다"고 11일 밝혔다. 범대위는 지난 9일 전체회의를 열어 “시행령 2차 개정시 피해주민들이 실질적으로 배상을 받을 수 있는 방',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '[포항=뉴시스] 강진구 기자 = 경북 포항11·15촉발지진 범시민대책위원회(공동위원장 이대공 김재동 허상호 공원식·이하 범대위)는 "정부가 추진하는 시행령 2차 개정 시 피해주민들에 대한 실질적인 배상 내용이 충분히 반영돼야 한다"고 11일 밝혔다. 범대위는 지난 9일 전체회의를 열어 “시행령 2차 개정시 피해주민들이 실질적으로 배상을 받을 수 있는 방'},
#    'published': 'Thu, 11 Jun 2020 07:02:52 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=2, tm_sec=52, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160252833',
#    'guidislink': False,
#    'authors': [{'name': '뉴시스'}],
#    'author': '뉴시스',
#    'author_detail': {'name': '뉴시스'},
#    'updated': '2020-06-11T07:02:52Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=2, tm_sec=52, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '성남 하나님의교회 신도 4명 추가확진..방판업체 확진자와 예배(종합)',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '성남 하나님의교회 신도 4명 추가확진..방판업체 확진자와 예배(종합)'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160224813'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/yonhap/20200611160224697uhwn.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160224813',
#    'summary': "(성남=연합뉴스) 최찬흥 기자 = 경기 성남시는 중원구 하대원동 '하나님의 교회' 신도 4명이 신종 코로나바이러스 감염증(코로나19) 확진 판정을 받았다고 11일 밝혔다. 앞서 이 교회 신도인 69세 남성(성남 149번 환자)과 그의 부인(성남 150번 환자)이 지난 9일 확진 판정이 나 신도 138명에 대한 전수검사가 진행중이다. 성남 149번 환자는",
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "(성남=연합뉴스) 최찬흥 기자 = 경기 성남시는 중원구 하대원동 '하나님의 교회' 신도 4명이 신종 코로나바이러스 감염증(코로나19) 확진 판정을 받았다고 11일 밝혔다. 앞서 이 교회 신도인 69세 남성(성남 149번 환자)과 그의 부인(성남 150번 환자)이 지난 9일 확진 판정이 나 신도 138명에 대한 전수검사가 진행중이다. 성남 149번 환자는"},
#    'published': 'Thu, 11 Jun 2020 07:02:24 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=2, tm_sec=24, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160224813',
#    'guidislink': False,
#    'authors': [{'name': '연합뉴스'}],
#    'author': '연합뉴스',
#    'author_detail': {'name': '연합뉴스'},
#    'updated': '2020-06-11T07:02:24Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=2, tm_sec=24, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '리치웨이 관련 116명, 탁구장發 60명..2주간 일평균 43.1명(종합)',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '리치웨이 관련 116명, 탁구장發 60명..2주간 일평균 43.1명(종합)'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160120768'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/newsis/20200611160120902uaqg.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160120768',
#    'summary': '[세종=뉴시스] 이연희 임재희 기자 = 인천 예수말씀실천교회 신종 코로나바이러스 감염증(코로나19) 확진 환자가 지난달 21일 서울 관악구 소재 리치웨이에 방문한 사실이 확인됐다. 이로써 리치웨이 관련 누적 확진자 수가 총 116명으로 늘었다. 서울 양천구 탁구장 관련 확진 환자도 60명까지 증가했으며 쿠팡물류센터, 개척교회, 군부대 등 수도권에서 집단',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '[세종=뉴시스] 이연희 임재희 기자 = 인천 예수말씀실천교회 신종 코로나바이러스 감염증(코로나19) 확진 환자가 지난달 21일 서울 관악구 소재 리치웨이에 방문한 사실이 확인됐다. 이로써 리치웨이 관련 누적 확진자 수가 총 116명으로 늘었다. 서울 양천구 탁구장 관련 확진 환자도 60명까지 증가했으며 쿠팡물류센터, 개척교회, 군부대 등 수도권에서 집단'},
#    'published': 'Thu, 11 Jun 2020 07:01:20 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=20, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160120768',
#    'guidislink': False,
#    'authors': [{'name': '뉴시스'}],
#    'author': '뉴시스',
#    'author_detail': {'name': '뉴시스'},
#    'updated': '2020-06-11T07:01:20Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=20, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '광주 신천지 교회·시설 강제 폐쇄 15일부터 해제',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '광주 신천지 교회·시설 강제 폐쇄 15일부터 해제'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160119767'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/yonhap/20200611160120031hufq.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160119767',
#    'summary': '(광주=연합뉴스) 장덕종 기자 = 광주시는 신종 코로나바이러스 감염증(코로나19) 확산을 막으려 광주 지역 신천지 교회 2곳에 내린 시설 폐쇄 및 출입금지 행정명령을 15일부터 해제한다고 11일 밝혔다. 부속 시설 18곳도 임대차 계약 기간 만료와 계약 해지 등의 이유로 행정명령을 해제했다. 시는 대구 신천지 교회 발 코로나19 확산으로 올해 2월 27일부',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(광주=연합뉴스) 장덕종 기자 = 광주시는 신종 코로나바이러스 감염증(코로나19) 확산을 막으려 광주 지역 신천지 교회 2곳에 내린 시설 폐쇄 및 출입금지 행정명령을 15일부터 해제한다고 11일 밝혔다. 부속 시설 18곳도 임대차 계약 기간 만료와 계약 해지 등의 이유로 행정명령을 해제했다. 시는 대구 신천지 교회 발 코로나19 확산으로 올해 2월 27일부'},
#    'published': 'Thu, 11 Jun 2020 07:01:19 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=19, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160119767',
#    'guidislink': False,
#    'authors': [{'name': '연합뉴스'}],
#    'author': '연합뉴스',
#    'author_detail': {'name': '연합뉴스'},
#    'updated': '2020-06-11T07:01:19Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=19, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': "[신차드라이브]하늘을 품은 지프 '랭글러 오버랜드 파워탑'",
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "[신차드라이브]하늘을 품은 지프 '랭글러 오버랜드 파워탑'"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160119766'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/etimesi/20200611160119771urtw.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160119766',
#    'summary': '어떠한 상황에서도 자신감 넘치는 사륜구동 자동차의 대명사. 많은 이들이 꼽는 지프의 매력이다. 스포츠유틸리티차량(SUV) 홍수 속에 79년 역사를 바탕으로 브랜드 정체성을 확립한 지프는 사륜구동차를 찾는 마니아층에 많은 사랑을 받고 있다. 랭글러는 지프의 방향성을 가장 명확히 보여주는 핵심 모델이다. 차량 크기로 분류되는 일반 SUV와 달리 오프로더라는 자',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '어떠한 상황에서도 자신감 넘치는 사륜구동 자동차의 대명사. 많은 이들이 꼽는 지프의 매력이다. 스포츠유틸리티차량(SUV) 홍수 속에 79년 역사를 바탕으로 브랜드 정체성을 확립한 지프는 사륜구동차를 찾는 마니아층에 많은 사랑을 받고 있다. 랭글러는 지프의 방향성을 가장 명확히 보여주는 핵심 모델이다. 차량 크기로 분류되는 일반 SUV와 달리 오프로더라는 자'},
#    'published': 'Thu, 11 Jun 2020 07:01:19 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=19, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160119766',
#    'guidislink': False,
#    'authors': [{'name': '전자신문'}],
#    'author': '전자신문',
#    'author_detail': {'name': '전자신문'},
#    'updated': '2020-06-11T07:01:19Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=19, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': "[카&테크]'시간단축'이 경쟁력이다, 자율주행車 시뮬레이션 기술",
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "[카&테크]'시간단축'이 경쟁력이다, 자율주행車 시뮬레이션 기술"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160109750'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/etimesi/20200611160110524rhns.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160109750',
#    'summary': '자율주행차 시대가 점차 현실로 다가오고 있다. 업체별로 차이는 있지만 이미 낮은 단계의 자율주행차가 제한된 도로 위를 달리고 있다. 사람이 타는 이동수단인만큼 운전 중에 일어날 수 있는 다양한 상황에서도 안전하게 주행하도록 신뢰성 확보에 열을 올리고 있다. 업체들은 실차에 첨단 자율주행 센서를 장착해 실도로 주행테스트를 하면서, 실제와 유사한 주행환경의 컴',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '자율주행차 시대가 점차 현실로 다가오고 있다. 업체별로 차이는 있지만 이미 낮은 단계의 자율주행차가 제한된 도로 위를 달리고 있다. 사람이 타는 이동수단인만큼 운전 중에 일어날 수 있는 다양한 상황에서도 안전하게 주행하도록 신뢰성 확보에 열을 올리고 있다. 업체들은 실차에 첨단 자율주행 센서를 장착해 실도로 주행테스트를 하면서, 실제와 유사한 주행환경의 컴'},
#    'published': 'Thu, 11 Jun 2020 07:01:09 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=9, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160109750',
#    'guidislink': False,
#    'authors': [{'name': '전자신문'}],
#    'author': '전자신문',
#    'author_detail': {'name': '전자신문'},
#    'updated': '2020-06-11T07:01:09Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=9, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': "7월부터 이어폰 등 3중 포장 안된다..업계 '발만 동동'",
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': "7월부터 이어폰 등 3중 포장 안된다..업계 '발만 동동'"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160105739'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/etimesi/20200611160105660apnt.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160105739',
#    'summary': '다음 달부터 도입되는 소형 전자제품 포장에 대한 정부 규제에 중소 가전업계가 비상이 걸렸다. 코로나19로 중국, 베트남 등으로부터 포장재 수입이 차질을 빚고 있기 때문이다. 업계는 새로운 포장 규칙 적용 시기를 최소 1년 이상 유예해 달라는 입장이다. 10일 환경부에 따르면 차량용 충전기, 케이블, 이어폰·헤드폰, 마우스, 300그램 이하 근거리 무선통신',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '다음 달부터 도입되는 소형 전자제품 포장에 대한 정부 규제에 중소 가전업계가 비상이 걸렸다. 코로나19로 중국, 베트남 등으로부터 포장재 수입이 차질을 빚고 있기 때문이다. 업계는 새로운 포장 규칙 적용 시기를 최소 1년 이상 유예해 달라는 입장이다. 10일 환경부에 따르면 차량용 충전기, 케이블, 이어폰·헤드폰, 마우스, 300그램 이하 근거리 무선통신'},
#    'published': 'Thu, 11 Jun 2020 07:01:05 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=5, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160105739',
#    'guidislink': False,
#    'authors': [{'name': '전자신문'}],
#    'author': '전자신문',
#    'author_detail': {'name': '전자신문'},
#    'updated': '2020-06-11T07:01:05Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=1, tm_sec=5, tm_wday=3, tm_yday=163, tm_isdst=0)},
#   {'title': '"전화금융사기 20~50대가 다수" 광주경찰 259명 검거, 23명 구속',
#    'title_detail': {'type': 'text/plain',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '"전화금융사기 20~50대가 다수" 광주경찰 259명 검거, 23명 구속'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://v.daum.net/v/20200611160038704'},
#     {'type': 'image/jpeg',
#      'href': 'https://t1.daumcdn.net/news/202006/11/NEWS1/20200611160039044yvib.jpg',
#      'rel': 'enclosure'}],
#    'link': 'https://v.daum.net/v/20200611160038704',
#    'summary': '(광주=뉴스1) 한산 기자 = 광주지방경찰청은 최근 2개월 동안 전화금융사기 특별단속을 벌여 259명을 검거하고 이 중 23명을 구속했다고 11일 밝혔다. 광주경찰은 4월6일 모든 부서가 참여한 전화금융사기 대응 태스크포스(TF)를 발족하고 집중단속을 벌이는 한편 다각적인 예방활동을 펼쳤다. 이에 따라 4월6일부터 지난 5일까지 전화금융사기와 관련해 2',
#    'summary_detail': {'type': 'text/html',
#     'language': 'ko-KR',
#     'base': 'https://media.daum.net/syndication/today_sisa.rss',
#     'value': '(광주=뉴스1) 한산 기자 = 광주지방경찰청은 최근 2개월 동안 전화금융사기 특별단속을 벌여 259명을 검거하고 이 중 23명을 구속했다고 11일 밝혔다. 광주경찰은 4월6일 모든 부서가 참여한 전화금융사기 대응 태스크포스(TF)를 발족하고 집중단속을 벌이는 한편 다각적인 예방활동을 펼쳤다. 이에 따라 4월6일부터 지난 5일까지 전화금융사기와 관련해 2'},
#    'published': 'Thu, 11 Jun 2020 07:00:38 GMT',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=0, tm_sec=38, tm_wday=3, tm_yday=163, tm_isdst=0),
#    'id': 'media:news:20200611160038704',
#    'guidislink': False,
#    'authors': [{'name': '뉴스1'}],
#    'author': '뉴스1',
#    'author_detail': {'name': '뉴스1'},
#    'updated': '2020-06-11T07:00:38Z',
#    'updated_parsed': time.struct_time(tm_year=2020, tm_mon=6, tm_mday=11, tm_hour=7, tm_min=0, tm_sec=38, tm_wday=3, tm_yday=163, tm_isdst=0)}],
#  'bozo': 0,
#  'headers': {'Content-Length': '7033',
#   'Expires': 'Thu, 11 Jun 2020 07:18:10 GMT',
#   'Date': 'Thu, 11 Jun 2020 07:14:10 GMT',
#   'Server': 'Apache',
#   'Cache-Control': 'public,s-maxage=240',
#   'Content-Language': 'ko-KR',
#   'Vary': 'Accept-Encoding',
#   'Content-Encoding': 'gzip',
#   'Content-Type': 'application/rss+xml;charset=UTF-8',
#   'Age': '179',
#   'Via': '1.1 Wcache(2.0)',
#   'Connection': 'keep-alive'},
#  'href': 'https://media.daum.net/syndication/today_sisa.rss',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'rss20',
#  'namespaces': {'dc': 'http://purl.org/dc/elements/1.1/'}}

# %%
links = [entry['link'] for entry in feeds['entries']]
from tqdm import tqdm_notebook
news_text = ''
for link in tqdm_notebook(links):
    article = newspaper.Article(links[0], language = 'ko')
    article.download()
    article.parse()
    news_text += article.text
news_text
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# '경기 부천 쿠팡물류센터발 신종 코로나바이러스 감염증(코로나19)으로 고3을 제외한 학년의 등교가 중지됐던 인천과 부천지역 학교들이 11일 등교수업을 재개했다. /뉴스1 © News1 정진욱 기자\n\n(서울=뉴스1) 장지훈 기자,정지형 기자 = 쿠팡물류센터발(發) 신종 코로나바이러스 감염증(코로나19) 여파로 등교수업을 중지했던 부천·인천지역 학교 493곳이 11일 등교수업을 재개하면서 등교 중지 학교가 16곳으로 급감했다.\n\n교육부에 따르면 이날 오전 10시 기준 등교를 중지한 학교는 인천 4곳, 서울 3곳, 경기 안양 1곳, 경기 성남 1곳, 경남 양산 3곳, 경북 영천 2곳, 경북 경산 1곳, 부산 1곳 등 총 16개 학교다. 등교수업을 하지 못한 학교가 전날 512곳에서 496곳 줄었다.\n\n쿠팡 부천물류센터에서 발생한 지역감염 확산으로 지난달 27일부터 고3을 제외한 모든 학년의 등교가 중지됐던 부천 251개 학교와 인천 부평구 153개 학교, 인천 계양구 89개 학교가 이날부터 등교를 재개한 게 영향을 미쳤다.\n\n지난달 20일 고3부터 등교수업을 시작한 이후 확진 판정을 받은 학생과 교직원은 10일 오후 4시 기준으로 총 14명으로 유지됐다. 학생 10명, 교직원 4명으로 지난 9일 같은 시간 기준과 비교해 변동이 없었다.\n\n등교수업이 시작된 후 발생한 학생 확진자는 고등학생이 6명으로 가장 많고 중학생과 초등학생이 각각 2명씩이다. 지역별로는 서울 3명, 인천 3명, 대구 2명, 부산 1명, 경기 1명이다.\n\n교직원은 인천(1명)과 경북(2명)에서 각각 초등학교, 고등학교 교사가 코로나19 확진 판정을 받았고 경기 지역에서는 유치원 운전사 1명이 확진 판정을 받는 일이 발생했다.\n\n교육부 관계자는 "등교수업 시작 이후 현재까지 학생 10만2504명, 교직원 1만121명이 진단검사를 받았고 확진자는 14명 나왔다"며 "학교 내 감염 사례는 아직 발생하지 않고 있다"고 말했다.\n\nhunhun@news1.kr경기 부천 쿠팡물류센터발 신종 코로나바이러스 감염증(코로나19)으로 고3을 제외한 학년의 등교가 중지됐던 인천과 부천지역 학교들이 11일 등교수업을 재개했다. /뉴스1 © News1 정진욱 기자\n\n(서울=뉴스1) 장지훈 기자,정지형 기자 = 쿠팡물류센터발(發) 신종 코로나바이러스 감염증(코로나19) 여파로 등교수업을 중지했던 부천·인천지역 학교 493곳이 11일 등교수업을 재개하면서 등교 중지 학교가 16곳으로 급감했다.\n\n교육부에 따르면 이날 오전 10시 기준 등교를 중지한 학교는 인천 4곳, 서울 3곳, 경기 안양 1곳, 경기 성남 1곳, 경남 양산 3곳, 경북 영천 2곳, 경북 경산 1곳, 부산 1곳 등 총 16개 학교다. 등교수업을 하지 못한 학교가 전날 512곳에서 496곳 줄었다.\n\n쿠팡 부천물류센터에서 발생한 지역감염 확산으로 지난달 27일부터 고3을 제외한 모든 학년의 등교가 중지됐던 부천 251개 학교와 인천 부평구 153개 학교, 인천 계양구 89개 학교가 이날부터 등교를 재개한 게 영향을 미쳤다.\n\n지난달 20일 고3부터 등교수업을 시작한 이후 확진 판정을 받은 학생과 교직원은 10일 오후 4시 기준으로 총 14명으로 유지됐다. 학생 10명, 교직원 4명으로 지난 9일 같은 시간 기준과 비교해 변동이 없었다.\n\n등교수업이 시작된 후 발생한 학생 확진자는 고등학생이 6명으로 가장 많고 중학생과 초등학생이 각각 2명씩이다. 지역별로는 서울 3명, 인천 3명, 대구 2명, 부산 1명, 경기 1명이다.\n\n교직원은 인천(1명)과 경북(2명)에서 각각 초등학교, 고등학교 교사가 코로나19 확진 판정을 받았고 경기 지역에서는 유치원 운전사 1명이 확진 판정을 받는 일이 발생했다.\n\n교육부 관계자는 "등교수업 시작 이후 현재까지 학생 10만2504명, 교직원 1만121명이 진단검사를 받았고 확진자는 14명 나왔다"며 "학교 내 감염 사례는 아직 발생하지 않고 있다"고 말했다.\n\nhunhun@news1.kr경기 부천 쿠팡물류센터발 신종 코로나바이러스 감염증(코로나19)으로 고3을 제외한 학년의 등교가 중지됐던 인천과 부천지역 학교들이 11일 등교수업을 재개했다. /뉴스1 © News1 정진욱 기자\n\n(서울=뉴스1) 장지훈 기자,정지형 기자 = 쿠팡물류센터발(發) 신종 코로나바이러스 감염증(코로나19) 여파로 등교수업을 중지했던 부천·인천지역 학교 493곳이 11일 등교수업을 재개하면서 등교 중지 학교가 16곳으로 급감했다.\n\n교육부에 따르면 이날 오전 10시 기준 등교를 중지한 학교는 인천 4곳, 서울 3곳, 경기 안양 1곳, 경기 성남 1곳, 경남 양산 3곳, 경북 영천 2곳, 경북 경산 1곳, 부산 1곳 등 총 16개 학교다. 등교수업을 하지 못한 학교가 전날 512곳에서 496곳 줄었다.\n\n쿠팡 부천물류센터에서 발생한 지역감염 확산으로 지난달 27일부터 고3을 제외한 모든 학년의 등교가 중지됐던 부천 251개 학교와 인천 부평구 153개 학교, 인천 계양구 89개 학교가 이날부터 등교를 재개한 게 영향을 미쳤다.\n\n지난달 20일 고3부터 등교수업을 시작한 이후 확진 판정을 받은 학생과 교직원은 10일 오후 4시 기준으로 총 14명으로 유지됐다. 학생 10명, 교직원 4명으로 지난 9일 같은 시간 기준과 비교해 변동이 없었다.\n\n등교수업이 시작된 후 발생한 학생 확진자는 고등학생이 6명으로 가장 많고 중학생과 초등학생이 각각 2명씩이다. 지역별로는 서울 3명, 인천 3명, 대구 2명, 부산 1명, 경기 1명이다.\n\n교직원은 인천(1명)과 경북(2명)에서 각각 초등학교, 고등학교 교사가 코로나19 확진 판정을 받았고 경기 지역에서는 유치원 운전사 1명이 확진 판정을 받는 일이 발생했다.\n\n교육부 관계자는 "등교수업 시작 이후 현재까지 학생 10만2504명, 교직원 1만121명이 진단검사를 받았고 확진자는 14명 나왔다"며 "학교 내 감염 사례는 아직 발생하지 않고 있다"고 말했다.\n\nhunhun@news1.kr경기 부천 쿠팡물류센터발 신종 코로나바이러스 감염증(코로나19)으로 고3을 제외한 학년의 등교가 중지됐던 인천과 부천지역 학교들이 11일 등교수업을 재개했다. /뉴스1 © News1 정진욱 기자\n\n(서울=뉴스1) 장지훈 기자,정지형 기자 = 쿠팡물류센터발(發) 신종 코로나바이러스 감염증(코로나19) 여파로 등교수업을 중지했던 부천·인천지역 학교 493곳이 11일 등교수업을 재개하면서 등교 중지 학교가 16곳으로 급감했다.\n\n교육부에 따르면 이날 오전 10시 기준 등교를 중지한 학교는 인천 4곳, 서울 3곳, 경기 안양 1곳, 경기 성남 1곳, 경남 양산 3곳, 경북 영천 2곳, 경북 경산 1곳, 부산 1곳 등 총 16개 학교다. 등교수업을 하지 못한 학교가 전날 512곳에서 496곳 줄었다.\n\n쿠팡 부천물류센터에서 발생한 지역감염 확산으로 지난달 27일부터 고3을 제외한 모든 학년의 등교가 중지됐던 부천 251개 학교와 인천 부평구 153개 학교, 인천 계양구 89개 학교가 이날부터 등교를 재개한 게 영향을 미쳤다.\n\n지난달 20일 고3부터 등교수업을 시작한 이후 확진 판정을 받은 학생과 교직원은 10일 오후 4시 기준으로 총 14명으로 유지됐다. 학생 10명, 교직원 4명으로 지난 9일 같은 시간 기준과 비교해 변동이 없었다.\n\n등교수업이 시작된 후 발생한 학생 확진자는 고등학생이 6명으로 가장 많고 중학생과 초등학생이 각각 2명씩이다. 지역별로는 서울 3명, 인천 3명, 대구 2명, 부산 1명, 경기 1명이다.\n\n교직원은 인천(1명)과 경북(2명)에서 각각 초등학교, 고등학교 교사가 코로나19 확진 판정을 받았고 경기 지역에서는 유치원 운전사 1명이 확진 판정을 받는 일이 발생했다.\n\n교육부 관계자는 "등교수업 시작 이후 현재까지 학생 10만2504명, 교직원 1만121명이 진단검사를 받았고 확진자는 14명 나왔다"며 "학교 내 감염 사례는 아직 발생하지 않고 있다"고 말했다.\n\nhunhun@news1.kr경기 부천 쿠팡물류센터발 신종 코로나바이러스 감염증(코로나19)으로 고3을 제외한 학 ...

# %%
kkma = Kkma()
nouns = kkma.nouns(news_text)
nouns = [n for n in nouns if len(n) > 1]
count = Counter(nouns)
tags = count.most_common(40)
tags
# Out:
# [('등교수업', 2),
#  ('경기', 1),
#  ('부천', 1),
#  ('쿠팡', 1),
#  ('쿠팡물류센터발', 1),
#  ('물류', 1),
#  ('센터', 1),
#  ('신종', 1),
#  ('코로나', 1),
#  ('코로나바이러스', 1),
#  ('이러스', 1),
#  ('감염증', 1),
#  ('코로나19', 1),
#  ('19', 1),
#  ('고3', 1),
#  ('제외', 1),
#  ('학년', 1),
#  ('등교', 1),
#  ('중지', 1),
#  ('인천', 1),
#  ('부천지역', 1),
#  ('지역', 1),
#  ('학교', 1),
#  ('11', 1),
#  ('11일', 1),
#  ('수업', 1),
#  ('재개', 1),
#  ('뉴스', 1),
#  ('뉴스1', 1),
#  ('정진', 1),
#  ('기자', 1),
#  ('서울', 1),
#  ('장지', 1),
#  ('장지훈', 1),
#  ('정지', 1),
#  ('정지형', 1),
#  ('여파', 1),
#  ('인천지역', 1),
#  ('493', 1),
#  ('493곳', 1)]

# %%
import matplotlib.pyplot as plt
import

wc = WordCloud(background_color ='white', width = 900, height = 900)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
