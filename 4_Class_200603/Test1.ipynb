# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("./Data/ign_game_reviews.csv",header=0)
data.shape
# Out:
# (18625, 11)

# %%
data.iloc[0:5, : ]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
data.iloc[:]
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# ...

# %%
data.iloc[:,0]
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 18620    18620
# 18621    18621
# 18622    18622
# 18623    18623
# 18624    18624
# Name: Unnamed: 0, Length: 18625, dtype: int64

# %%
data.iloc[[1,9],:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 9           9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 9          /games/total-war-battles-shogun/pc-142564                PC    7.0
#
#         genre editors_choice  release_year  release_month  release_day
# 1  Platformer              Y          2012              9           12
# 9    Strategy              N          2012              9           11

# %%
data.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
df = data.iloc[:,1:]

# %%
df.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# ...

# %%
df.loc[:5,'score']
# Out:
# 0    9.0
# 1    9.0
# 2    8.5
# 3    8.5
# 4    8.5
# 5    7.0
# Name: score, dtype: float64

# %%
df.columns
# Out:
# Index(['score_phrase', 'title', 'url', 'platform', 'score', 'genre',
#        'editors_choice', 'release_year', 'release_month', 'release_day'],
#       dtype='object')

# %%
df.loc[:5,['score','release_year']]
# Out:
#    score  release_year
# 0    9.0          2012
# 1    9.0          2012
# 2    8.5          2012
# 3    8.5          2012
# 4    8.5          2012
# 5    7.0          2012

# %%
type(df["score"])
# Out:
# pandas.core.series.Series

# %%
df["score"].sum()
df["score"].mean()
# Out:
# 6.950459060402666

# %%
df.mean(axis=0)
df.mean(axis=1)
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
#           ...
# 18620    514.650
# 18621    515.000
# 18622    513.950
# 18623    515.000
# 18624    515.000
# Length: 18625, dtype: float64

# %%
df.count()
# Out:
# score_phrase      18625
# title             18625
# url               18625
# platform          18625
# score             18625
# genre             18589
# editors_choice    18625
# release_year      18625
# release_month     18625
# release_day       18625
# dtype: int64

# %%
df.describe()
# Out:
#               score  release_year  release_month   release_day
# count  18625.000000  18625.000000    18625.00000  18625.000000
# mean       6.950459   2006.515329        7.13847     15.603866
# std        1.711736      4.587529        3.47671      8.690128
# min        0.500000   1970.000000        1.00000      1.000000
# 25%        6.000000   2003.000000        4.00000      8.000000
# 50%        7.300000   2007.000000        8.00000     16.000000
# 75%        8.200000   2010.000000       10.00000     23.000000
# max       10.000000   2016.000000       12.00000     31.000000

# %%
df.corr()
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062716       0.007632     0.020079
# release_year   0.062716      1.000000      -0.115515     0.016867
# release_month  0.007632     -0.115515       1.000000    -0.067964
# release_day    0.020079      0.016867      -0.067964     1.000000

# %%
df["score"]/2
# Out:
# 0        4.50
# 1        4.50
# 2        4.25
# 3        4.25
# 4        4.25
#          ...
# 18620    3.80
# 18621    4.50
# 18622    2.90
# 18623    5.00
# 18624    5.00
# Name: score, Length: 18625, dtype: float64

# %%
filter = df["score"]>7

# %%
filter
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 18620     True
# 18621     True
# 18622    False
# 18623     True
# 18624     True
# Name: score, Length: 18625, dtype: bool

# %%
df[filter]
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# ...            ...                                                ...
# 18619         Good                                    Human Fall Flat
# 18620         Good                          Tokyo Mirage Sessions #FE
# 18621      Amazing                  LEGO Star Wars: The Force Awakens
# 18623  Masterpiece                                             Inside
# 18624  Masterpiece                                             Inside
#
#                                                      url          platform  \
# ...

# %%
df2 = df[filter]

# %%
df2.shape
# Out:
# (9800, 10)

# %%
df2.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# ...

# %%
df['platform']
# Out:
# 0        PlayStation Vita
# 1        PlayStation Vita
# 2                    iPad
# 3                Xbox 360
# 4           PlayStation 3
#                ...
# 18620               Wii U
# 18621       PlayStation 4
# 18622       PlayStation 4
# 18623            Xbox One
# 18624                  PC
# Name: platform, Length: 18625, dtype: object

# %%
filter2 = (df["score"]>7) & (df["platform"]=="Xbox 360")

# %%
df3 = df[filter]
df3
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# ...            ...                                                ...
# 18619         Good                                    Human Fall Flat
# 18620         Good                          Tokyo Mirage Sessions #FE
# 18621      Amazing                  LEGO Star Wars: The Force Awakens
# 18623  Masterpiece                                             Inside
# 18624  Masterpiece                                             Inside
#
#                                                      url          platform  \
# ...

# %%
df3 = df[filter2]
df3.shape
# Out:
# (909, 10)

# %%
df3.head() #head는 앞부분만 출력됨.
# Out:
#    score_phrase                                              title  \
# 3         Great                                             NHL 13
# 11         Good                            Tekken Tag Tournament 2
# 13      Amazing                                  Mark of the Ninja
# 21         Good                           Mass Effect 3: Leviathan
# 37      Amazing  The Walking Dead: The Game -- Episode 3: Long ...
#
#                                                   url  platform  score  \
# 3                       /games/nhl-13/xbox-360-128182  Xbox 360    8.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581  Xbox 360    7.5
# 13    /games/mark-of-the-ninja-135615/xbox-360-129276  Xbox 360    9.0
# 21     /games/mass-effect-3-leviathan/xbox-360-138918  Xbox 360    7.5
# 37  /games/the-walking-dead-season-1-episode-3/xbo...  Xbox 360    9.0
#
#                 genre editors_choice  release_year  release_month  release_day
# ...

# %%
df3.iloc[:]
# Out:
#       score_phrase                                              title  \
# 3            Great                                             NHL 13
# 11            Good                            Tekken Tag Tournament 2
# 13         Amazing                                  Mark of the Ninja
# 21            Good                           Mass Effect 3: Leviathan
# 37         Amazing  The Walking Dead: The Game -- Episode 3: Long ...
# ...            ...                                                ...
# 17935         Good                                    Costume Quest 2
# 17952      Amazing                          Pro Evolution Soccer 2015
# 17955        Great                                          Far Cry 4
# 18002        Great                                      Resident Evil
# 18328         Good                                   Guitar Hero Live
#
#                                                      url  platform  score  \
# ...

# %%
df3["score"].plot(kind="hist")

# %%
filter3 = df["platform"]=="Xbox 360"

# %%
df[filter3]
# Out:
#       score_phrase                        title  \
# 3            Great                       NHL 13
# 6            Awful          Double Dragon: Neon
# 11            Good      Tekken Tag Tournament 2
# 13         Amazing            Mark of the Ninja
# 19            Good  JoJo's Bizarre Adventure HD
# ...            ...                          ...
# 17955        Great                    Far Cry 4
# 18002        Great                Resident Evil
# 18043      Painful                     Rugby 15
# 18323         Good  Call of Duty: Black Ops III
# 18328         Good             Guitar Hero Live
#
#                                                      url  platform  score  \
# 3                          /games/nhl-13/xbox-360-128182  Xbox 360    8.5
# 6              /games/double-dragon-neon/xbox-360-131320  Xbox 360    3.0
# 11        /games/tekken-tag-tournament-2/xbox-360-124581  Xbox 360    7.5
# 13       /games/mark-of-the-ninja-135615/xbox-360-129276  Xbox 360    9.0
# ...

# %%
df[df["platform"]=="Xbox 360"]["score"].plot(kind="hist")
