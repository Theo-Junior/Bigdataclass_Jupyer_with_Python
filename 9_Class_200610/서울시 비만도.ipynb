# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import platform
import folium
import json
geo_path='./05. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
    
df_raw = pd.read_excel('./서울시 비만도 통계.xlsx', encoding = 'utf-8', index_col=0)
df_raw
# Out:
#        자치구         비만도          비만도.1            비만도.2           비만도.3
# 기간
# 기간     자치구      비만도 분포         비만도 분포           비만도 분포  체질량지수(BMI)(평균)
# 기간     자치구  비만(BMI≥25)  저체중(BMI<18.5)  정상(18.5≤BMI＜25)  체질량지수(BMI)(평균)
# 2018   서울시        31.3              -                -               -
# 2018   종로구        34.5            5.7             59.8            23.8
# 2018    중구        31.6            8.8             59.6            23.2
# 2018   용산구        30.2            1.1             68.7            23.8
# 2018   성동구        32.8            4.3               63            23.7
# 2018   광진구        30.5            6.2             63.3            23.5
# 2018  동대문구        26.4              4             69.5            23.5
# 2018   중랑구        38.8            5.6             55.7            24.1
# 2018   성북구          39            4.2             56.8            24.2
# 2018   강북구        31.3            6.2             62.6            23.7
# ...

# %%
df2 = df.drop(['비만(BMI≥25)','저체중(BMI<18.5)','정상(18.5≤BMI＜25)'], axis=1)
df2
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data=geo_str, data = df2, columns = [df2.index ,'바보멍쳥이메롱(BMI)(평균)'], fill_color = 'PuRd', key_on='feature.id')
map
